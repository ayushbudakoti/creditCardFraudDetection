# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushbudakoti/creditCardFraudDetection/blob/master/Credit_Card_Fraud_Detection_Using_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns = None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 41678  40781 -0.447381  1.134089  0.534095 -0.192366  1.344408 -0.370402
# 41679  40782  1.133168  0.406826  0.956032  2.315761 -0.242409  0.225013
# 41680  40783 -0.536190  1.355132  0.064049  0.884589  0.581654 -0.179437
# 41681  40783 -0.498757  0.332449  1.917148 -2.340131 -1.098398 -0.863136
# 41682  40784 -0.621229 -0.733600       NaN       NaN       NaN       NaN
#
#              V7        V8        V9       V10       V11       V12       V13  \
# 41678  1.088646 -0.094025 -0.444502 -0.966513  0.451697 -0.902774 -1.552331
# 41679 -0.295703  0.130832 -0.768433  0.824612  0.890682  0.723309  0.616959
# 41680  0.466058  0.213312 -0.130088 -0.023518  1.349797 -0.865139 -2.188325
# 41681 -0.055820 -0.084046  1.673677 -1.560954  0.051092  1.290632  1.722273
# 41682       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
data.shape
# Out:
# (41683, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41683 entries, 0 to 41682
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    41683 non-null  int64
#  1   V1      41683 non-null  float64
#  2   V2      41683 non-null  float64
#  3   V3      41682 non-null  float64
#  4   V4      41682 non-null  float64
#  5   V5      41682 non-null  float64
#  6   V6      41682 non-null  float64
#  7   V7      41682 non-null  float64
#  8   V8      41682 non-null  float64
#  9   V9      41682 non-null  float64
#  10  V10     41682 non-null  float64
#  11  V11     41682 non-null  float64
#  12  V12     41682 non-null  float64
#  13  V13     41682 non-null  float64
#  14  V14     41682 non-null  float64
#  15  V15     41682 non-null  float64
#  16  V16     41682 non-null  float64
#  17  V17     41682 non-null  float64
#  18  V18     41682 non-null  float64
#  19  V19     41682 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
data['Amount'] = sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'],axis = 1 )

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (40727, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0.0    40618
# 1.0      108
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
sns.countplot(data['Class'])
plt.show()

# %%
x = data.drop(['Class'],axis = 1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Remove rows with missing values in the training and test data
x_train = x_train.dropna()
x_test = x_test.dropna()
y_train = y_train[x_train.index]  # Ensure y_train and x_train are in sync
y_test = y_test[x_test.index]     # Ensure y_test and x_test are in sync

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Define the classifiers
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

# Iterate through the classifiers
for name, clf in classifier.items():
    print(f"\n========== {name} ==========")  # Correct escape sequence \n
    clf.fit(x_train, y_train)  # Fit the model on the training data
    y_pred = clf.predict(x_test)  # Predict using the test data

    # Calculate and print performance metrics
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred):.4f}")
    print(f"Recall: {recall_score(y_test, y_pred):.4f}")
    print(f"F1 score: {f1_score(y_test, y_pred):.4f}")
# Out:
# ========== Logistic Regression ==========
# Accuracy: 0.9985
# Precision: 0.5714
# Recall: 0.8000
# F1 score: 0.6667
#
# ========== Decision Tree Classifier ==========
# Accuracy: 0.9996
# Precision: 0.9286
# Recall: 0.8667
# F1 score: 0.8966

# %%
Undersampling

# %%
normal = data[data['Class'] == 0]
fraud = data[data['Class'] == 1]

# %%
normal.shape
# Out:
# (40618, 30)

# %%
fraud.shape
# Out:
# (108, 30)

# %%
normal_sample = normal.sample(n = 108)

# %%
normal_sample.shape
# Out:
# (108, 30)

# %%
new_data = pd.concat([normal_sample,fraud], ignore_index =  True)

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -2.145531  0.583446  1.239023  0.322204  0.674411 -0.714822  0.189104
# 1 -2.130285 -1.338581  1.537497 -0.016659  0.184007  2.353830  0.401288
# 2 -1.130622  1.137389  1.593538 -1.513927 -0.093988 -0.403795  0.481942
# 3  1.337295 -0.449362  0.692929 -0.731860 -1.107054 -0.807865 -0.595242
# 4 -1.475982 -0.626053  1.348630  2.045755 -1.335515  1.991518  2.099581
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.037495 -0.201684  0.604833  1.248015  0.077038 -0.494921 -0.314894
# 1 -0.512794  0.902298  1.734839 -0.859365  0.353111  0.630828 -2.217705
# 2  0.204012 -0.025223 -0.011470  1.785286  1.199608  0.577665 -0.098633
# 3 -0.098953 -1.143025  0.751259  1.809387  0.593557  0.758602 -0.093340
# 4  0.371000 -1.395255 -0.186329  1.226335 -0.245500 -0.946200  0.470959
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
x = new_data.drop(['Class'],axis = 1)
y = new_data['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Define the classifiers
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

# Iterate through the classifiers
for name, clf in classifier.items():
    print(f"\n========== {name} ==========")  # Correct escape sequence \n
    clf.fit(x_train, y_train)  # Fit the model on the training data
    y_pred = clf.predict(x_test)  # Predict using the test data

    # Calculate and print performance metrics
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred):.4f}")
    print(f"Recall: {recall_score(y_test, y_pred):.4f}")
    print(f"F1 score: {f1_score(y_test, y_pred):.4f}")
# Out:
# ========== Logistic Regression ==========
# Accuracy: 0.9773
# Precision: 1.0000
# Recall: 0.9630
# F1 score: 0.9811
#
# ========== Decision Tree Classifier ==========
# Accuracy: 0.9545
# Precision: 1.0000
# Recall: 0.9259
# F1 score: 0.9615

# %%
OVERSAMPLING

# %%
x = data.drop(['Class'],axis = 1)
y = data['Class']

# %%
x.shape
# Out:
# (40727, 29)

# %%
y.shape
# Out:
# (40727,)

# %%
from imblearn.over_sampling import SMOTE

# %%
x = x.fillna(0)  # Replace with 0

# %%
x_res, y_res = SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0.0    40619
# 1.0    40619
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x_res, y_res, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Define the classifiers
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

# Iterate through the classifiers
for name, clf in classifier.items():
    print(f"\n========== {name} ==========")  # Correct escape sequence \n
    clf.fit(x_train, y_train)  # Fit the model on the training data
    y_pred = clf.predict(x_test)  # Predict using the test data

    # Calculate and print performance metrics
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred):.4f}")
    print(f"Recall: {recall_score(y_test, y_pred):.4f}")
    print(f"F1 score: {f1_score(y_test, y_pred):.4f}")
# Out:
# ========== Logistic Regression ==========
# Accuracy: 0.9786
# Precision: 0.9820
# Recall: 0.9747
# F1 score: 0.9784
#
# ========== Decision Tree Classifier ==========
# Accuracy: 0.9985
# Precision: 0.9980
# Recall: 0.9990
# F1 score: 0.9985

# %%
dtc= DecisionTreeClassifier()
dtc.fit(x_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc, "credit card model.pkl")
# Out:
# ['credit card model.pkl']

# %%
model = joblib.load("credit card model.pkl")

# %%
pred = model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# 0.0

# %%
if pred[0] == 0:
    print("Normal Transcation")
else:
    print("Fraud Transcation")
# Out:
# Normal Transcation
